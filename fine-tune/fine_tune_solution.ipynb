# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments
from peft import LoraConfig, TaskType, PeftModel
from trl import SFTTrainer
import torch
from sklearn.model_selection import train_test_split
import random

# %%
def load_csv_dataset(file_path, train_size=0.95, random_state=42):
    df = pd.read_csv(file_path)
    
    df['text'] = df.apply(lambda row: f"Translate the following natural language question to First Order Logic (FOL). Please respond with only the FOL statement. Don't include additional text.\nQuestion: {row['Question']}\nFOL Query: {row['FOL Query']}", axis=1)
    
    train_df, val_df = train_test_split(df, train_size=train_size, random_state=random_state)
    
    return {
        "train": Dataset.from_pandas(train_df),
        "validation": Dataset.from_pandas(val_df)
    }

# %%
def test_model(model, tokenizer, test_questions):
    model.eval()
    results = []
    
    for question, true_fol in test_questions:
        input_text = f"Translate the following natural language question to First Order Logic (FOL). Please respond with only the FOL statement. Don't include additional text. \nQuestion: {question}\nFOL Query:"
        input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to(model.device)
        
        with torch.no_grad():
            output = model.generate(input_ids, max_new_tokens=100, num_return_sequences=1, temperature=0.7)
        
        generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
        fol_query = generated_text.split("FOL Query:")[-1].strip()
        results.append({"question": question, "input": input_text, "generated_fol": fol_query, "true_fol": true_fol})
    
    return results

# %%
dataset = load_csv_dataset("question_query_train.csv")
print("Dataset loaded:", dataset)
# Out:
# Dataset loaded: {'train': Dataset({
#     features: ['Question', 'FOL Query', 'text', '__index_level_0__'],
#     num_rows: 408
# }), 'validation': Dataset({
#     features: ['Question', 'FOL Query', 'text', '__index_level_0__'],
#     num_rows: 22
# })}

# %% [markdown]
# ## Phi-3

# %%
# model_name = "microsoft/Phi-3-mini-4k-instruct"
# model_id = "microsoft/Phi-3-mini-4k-instruct"
# device_map = 'auto'

# if torch.cuda.is_bf16_supported():
#   compute_dtype = torch.bfloat16
#   attn_implementation = 'flash_attention_2'
# # If bfloat16 is not supported, 'compute_dtype' is set to 'torch.float16' and 'attn_implementation' is set to 'sdpa'.
# else:
#   compute_dtype = torch.float16
#   attn_implementation = 'sdpa'

# # compute_dtype = torch.float16
# # attn_implementation = 'sdpa'

# # Model and tokenizer
# tokenizer = AutoTokenizer.from_pretrained(
#     model_id, 
#     # trust_remote_code=True, 
#     # add_eos_token=True, 
#     # use_fast=True
# )

# # The padding token is set to the unknown token.
# # tokenizer.pad_token = tokenizer.unk_token

# # The ID of the padding token is set to the ID of the unknown token.
# # tokenizer.pad_token_id = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)

# # The padding side is set to 'left', meaning that padding tokens will be added to the left (start) of the sequence.
# # tokenizer.padding_side = 'left'

# # 'AutoModelForCausalLM.from_pretrained' is a method that loads a pre-trained model for causal language modeling from the Hugging Face Model Hub.
# # 'model_id' is passed as an argument to specify which model to load.
# # 'torch_dtype' is set to the compute data type determined earlier.
# # 'trust_remote_code' is set to True to trust the remote code in the model files.
# # 'device_map' is passed as an argument to specify the device mapping for distributed training.
# # 'attn_implementation' is set to the attention implementation determined earlier.
# model = AutoModelForCausalLM.from_pretrained(
#     model_id, trust_remote_code=True, 
#     device_map=device_map,
#     torch_dtype=compute_dtype,
#     attn_implementation=attn_implementation
# )

# %%
# lora_r = 16
# lora_alpha = 16
# lora_dropout = 0.05
# target_modules = ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]

# peft_config = LoraConfig(
#     r=lora_r,
#     lora_alpha=lora_alpha,
#     lora_dropout=lora_dropout,
#     task_type=TaskType.CAUSAL_LM,
#     target_modules=target_modules,
# )

# # Training arguments
# args = TrainingArguments(
#     output_dir="./phi-3-mini-LoRA-nl-to-fol",
#     evaluation_strategy="steps",
#     do_eval=True,
#     optim="adamw_torch",
#     per_device_train_batch_size=8,
#     gradient_accumulation_steps=4,
#     per_device_eval_batch_size=8,
#     log_level="debug",
#     save_strategy="epoch",
#     logging_steps=100,
#     learning_rate=1e-4,
#     fp16=not torch.cuda.is_bf16_supported(),
#     bf16=torch.cuda.is_bf16_supported(),
#     eval_steps=100,
#     num_train_epochs=17,
#     warmup_ratio=0.1,
#     lr_scheduler_type="linear",
#     # report_to="wandb",
#     seed=42,
# )

# # Initialize SFTTrainer
# trainer = SFTTrainer(
#     model=model,
#     train_dataset=dataset['train'],
#     eval_dataset=dataset['validation'],
#     peft_config=peft_config,
#     dataset_text_field="text",
#     max_seq_length=512,
#     tokenizer=tokenizer,
#     args=args,
# )

# %%
# # Save the fine-tuned model
# trainer.save_model("./phi-3-mini-LoRA-nl-to-fol-final")

# # Load the fine-tuned model
# fine_tuned_model = PeftModel.from_pretrained(model, "./phi-3-mini-LoRA-nl-to-fol-final")

# # Test model after fine-tuning
# print("Testing model after fine-tuning:")
# after_results = test_model(fine_tuned_model, tokenizer, test_questions)
# for result in after_results:
#     print(f"Question: {result['question']}")
#     print(f"Generated FOL: {result['generated_fol']}")
#     print(f"True FOL: {result['true_fol']}\n")

# %%
# # Save the entire model (base + LoRA) to a single file
# fine_tuned_model = fine_tuned_model.merge_and_unload()
# fine_tuned_model.save_pretrained("./phi-3-mini-nl-to-fol-merged")
# tokenizer.save_pretrained("./phi-3-mini-nl-to-fol-merged")
# print("Merged model saved to: ./phi-3-mini-nl-to-fol-merged")

# %% [markdown]
# ## GPT 2

# %%
model_name = "gpt2"
model_id = "gpt2"
device_map = 'auto'


tokenizer = AutoTokenizer.from_pretrained(
    model_id, 
)

model = AutoModelForCausalLM.from_pretrained(
    model_id, trust_remote_code=True, 
    device_map=device_map,
)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
test_questions = random.sample(list(zip(dataset['validation']['Question'], dataset['validation']['FOL Query'])), 1)

# Test model before fine-tuning
print("Testing model before fine-tuning:")
before_results = test_model(model, tokenizer, test_questions)
for result in before_results:
    print(f"Question: {result['question']}")
    print(f"Generated FOL: {result['generated_fol']}")
    print(f"True FOL: {result['true_fol']}\n")
# Out:
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Testing model before fine-tuning:
# Question: Can you spot a Mini Cooper on the left?
# Generated FOL: Question: Can you spot a Mini Cooper on the left?
# Question: Can you spot a Mini Cooper on the right?
# Question: Can you spot a Mini Cooper on the left?
# Question: Can you spot a Mini Cooper on the right?
# Question: Can you spot a Mini Cooper on the left?
# Question: Can you spot a Mini Cooper on the right?
# Question: Can
# True FOL: TypeOf(x, MiniCooper)^InitialLocation(x, NearLeft)

# %%
dataset
# Out:
# {'train': Dataset({
#      features: ['Question', 'FOL Query', 'text', '__index_level_0__'],
#      num_rows: 408
#  }),
#  'validation': Dataset({
#      features: ['Question', 'FOL Query', 'text', '__index_level_0__'],
#      num_rows: 22
#  })}

# %%
lora_r = 8  # Reduced from 16 to 8 for GPT-2
lora_alpha = 16
lora_dropout = 0.05
target_modules = ["c_attn", "c_proj", "c_fc"]  # GPT-2 specific target modules

peft_config = LoraConfig(
    r=lora_r,
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    task_type=TaskType.CAUSAL_LM,
    target_modules=target_modules,
    bias="none",  # GPT-2 doesn't use bias in attention layers
)

# Training arguments
args = TrainingArguments(
    output_dir="./gpt2-LoRA-nl-to-fol-2",
    evaluation_strategy="steps",
    do_eval=True,
    optim="adamw_torch",
    per_device_train_batch_size=4,  # Reduced from 8 to 4 due to GPT-2's larger size
    gradient_accumulation_steps=8,  # Increased from 4 to 8 to compensate for smaller batch size
    per_device_eval_batch_size=4,  # Reduced from 8 to 4
    log_level="info",  # Changed from "debug" to "info" for less verbose output
    save_strategy="epoch",
    logging_steps=100,  # Reduced from 100 to 50 for more frequent logging
    learning_rate=5e-5,  # Reduced from 1e-4 to 5e-5 for GPT-2
    fp16=True,  # GPT-2 works well with fp16
    eval_steps=100,  # Reduced from 100 to 50 for more frequent evaluation
    num_train_epochs=200,  # Reduced from 17 to 3 as GPT-2 might converge faster
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",  # Changed from "linear" to "cosine" for potentially better performance
    # report_to="wandb",  # Commented out as per your original code
    seed=42,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset['train'],
    eval_dataset=dataset['validation'],
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=256,  # Reduced from 512 to 256 for GPT-2
    tokenizer=tokenizer,
    args=args,
)
# Out:
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field, max_seq_length. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/peft/tuners/lora/layer.py:1091: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:283: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:321: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/408 [00:00<?, ? examples/s]
# Map:   0%|          | 0/22 [00:00<?, ? examples/s]
# You have loaded a model on multiple GPUs. `is_model_parallel` attribute will be force-set to `True` to avoid any unexpected behavior such as device placement mismatching.
# Using auto half precision backend

# %%
# Start training
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 408
#   Num Epochs = 200
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 8
#   Total optimization steps = 2,400
#   Number of trainable parameters = 1,179,648
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: imrankabir1996 (imrankabir1996-penn-state). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.3
# Run data is saved locally in <code>/home/ibk5106/projects/projects/FOL/llama/wandb/run-20241006_204720-z4xxlpo9</code>
# Syncing run <strong><a href='https://wandb.ai/imrankabir1996-penn-state/huggingface/runs/z4xxlpo9' target="_blank">./gpt2-LoRA-nl-to-fol-2</a></strong> to <a href='https://wandb.ai/imrankabir1996-penn-state/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/imrankabir1996-penn-state/huggingface' target="_blank">https://wandb.ai/imrankabir1996-penn-state/huggingface</a>
#  View run at <a href='https://wandb.ai/imrankabir1996-penn-state/huggingface/runs/z4xxlpo9' target="_blank">https://wandb.ai/imrankabir1996-penn-state/huggingface/runs/z4xxlpo9</a>
#     <div>
#
#       <progress value='2400' max='2400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2400/2400 17:00, Epoch 188/200]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>4.206900</td>
#       <td>3.650223</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.721400</td>
#       <td>1.064592</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.711700</td>
#       <td>0.438406</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.444200</td>
#       <td>0.344376</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.369800</td>
#       <td>0.296572</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.330700</td>
#       <td>0.277749</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.308000</td>
#       <td>0.262560</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.287700</td>
#       <td>0.256040</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.274600</td>
#       <td>0.253634</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.263300</td>
#       <td>0.245728</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.251400</td>
#       <td>0.245423</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.243300</td>
#       <td>0.241302</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.237400</td>
#       <td>0.238841</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.233200</td>
#       <td>0.235780</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.227200</td>
#       <td>0.236612</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.223500</td>
#       <td>0.236412</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.220700</td>
#       <td>0.234428</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.220800</td>
#       <td>0.234749</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.214900</td>
#       <td>0.233943</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.216000</td>
#       <td>0.234262</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.214500</td>
#       <td>0.233864</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.213800</td>
#       <td>0.233831</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.214500</td>
#       <td>0.233844</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.214300</td>
#       <td>0.233788</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-12
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-12/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-12/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-25
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-25/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-38
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-38/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-38/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-51
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-51/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-51/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-63
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-63/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-63/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-76
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-76/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-76/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-89
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-89/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-89/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-102
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-102/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-102/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-114
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-114/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-114/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-127
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-127/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-127/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-140
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-140/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-140/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-153
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-153/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-153/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-165
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-165/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-165/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-178
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-178/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-178/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-191
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-191/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-191/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-204
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-204/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-204/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-216
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-216/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-216/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-229
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-229/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-229/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-242
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-242/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-242/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-255
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-255/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-255/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-267
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-267/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-267/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-280
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-280/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-280/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-293
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-293/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-293/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-306
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-306/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-306/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-318
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-318/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-318/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-331
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-331/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-331/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-344
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-344/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-344/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-357
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-357/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-357/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-369
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-369/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-369/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-382
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-382/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-382/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-395
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-395/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-395/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-408
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-408/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-408/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-420
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-420/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-420/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-433
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
# ...
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2282/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2282/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2295
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2295/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2295/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2307
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2307/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2307/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2320
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2320/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2320/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2333
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2333/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2333/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2346
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2346/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2346/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2358
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2358/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2358/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2371
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2371/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2371/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2384
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2384/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2384/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2397
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2397/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2397/special_tokens_map.json
#
# ***** Running Evaluation *****
#   Num examples = 22
#   Batch size = 4
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400/special_tokens_map.json
# Saving model checkpoint to ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400/tokenizer_config.json
# Special tokens file saved in ./gpt2-LoRA-nl-to-fol-2/checkpoint-2400/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=2400, training_loss=0.544321772257487, metrics={'train_runtime': 1022.1581, 'train_samples_per_second': 79.831, 'train_steps_per_second': 2.348, 'total_flos': 3701730039607296.0, 'train_loss': 0.544321772257487, 'epoch': 188.23529411764707})

# %%
# Save the fine-tuned model
trainer.save_model("./gpt-2-LoRA-nl-to-fol-final-2")

# Load the fine-tuned model
fine_tuned_model = PeftModel.from_pretrained(model, "./gpt-2-LoRA-nl-to-fol-final-2")

# Test model after fine-tuning
print("Testing model after fine-tuning:")
after_results = test_model(fine_tuned_model, tokenizer, test_questions)
for result in after_results:
    print(f"Question: {result['question']}")
    print(f"Input: {result['input']}")
    print(f"Generated FOL: {result['generated_fol']}")
    print(f"True FOL: {result['true_fol']}\n")
# Out:
# Saving model checkpoint to ./gpt-2-LoRA-nl-to-fol-final-2
# loading configuration file config.json from cache at /home/ibk5106/.cache/huggingface/hub/models--gpt2/snapshots/607a30d783dfa663caf39e06633721c8d4cfcd7e/config.json
# Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# tokenizer config file saved in ./gpt-2-LoRA-nl-to-fol-final-2/tokenizer_config.json
# Special tokens file saved in ./gpt-2-LoRA-nl-to-fol-final-2/special_tokens_map.json
# /data/anaconda/anaconda3/envs/openelm/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Testing model after fine-tuning:
# Question: Can you spot a Mini Cooper on the left?
# Input: Translate the following natural language question to First Order Logic (FOL). Please respond with only the FOL statement. Don't include additional text.
# Question: Can you spot a Mini Cooper on the left?
# FOL Query:
# Generated FOL: TypeOf(x, Car)^InitialLocation(x, Left)^TypeOf(y, Truck)^InitialLocation(y, Right)^InitialLocation(x, Right)^ComeClose(x, y)^InitialLocation(y, Left)^ComeClose(y, x)^InitialLocation(x, Right)^InitialLocation(y, Left)^ComeClose(y, x)^InitialLocation(x, Right)^InitialLocation(y
# True FOL: TypeOf(x, MiniCooper)^InitialLocation(x, NearLeft)

# %%
# Save the entire model (base + LoRA) to a single file
fine_tuned_model = fine_tuned_model.merge_and_unload()
fine_tuned_model.save_pretrained("./gpt-2-nl-to-fol-merged")
tokenizer.save_pretrained("./gpt-2-nl-to-fol-merged")
print("Merged model saved to: ./gpt-2-nl-to-fol-merged")
# Out:
# Configuration saved in ./gpt-2-nl-to-fol-merged/config.json
# Configuration saved in ./gpt-2-nl-to-fol-merged/generation_config.json
# Model weights saved in ./gpt-2-nl-to-fol-merged/model.safetensors
# tokenizer config file saved in ./gpt-2-nl-to-fol-merged/tokenizer_config.json
# Special tokens file saved in ./gpt-2-nl-to-fol-merged/special_tokens_map.json
# Merged model saved to: ./gpt-2-nl-to-fol-merged

# %%
model_name = "./gpt-2-nl-to-fol-merged"
model_id = "./gpt-2-nl-to-fol-merged"
device_map = 'auto'


tokenizer = AutoTokenizer.from_pretrained(
    model_id, 
)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map=device_map,
)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# loading file vocab.json
# loading file merges.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json
# loading configuration file ./gpt-2-nl-to-fol-merged/config.json
# Model config GPT2Config {
#   "_name_or_path": "./gpt-2-nl-to-fol-merged",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.44.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# loading weights file ./gpt-2-nl-to-fol-merged/model.safetensors
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
#
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# All the weights of GPT2LMHeadModel were initialized from the model checkpoint at ./gpt-2-nl-to-fol-merged.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.
# loading configuration file ./gpt-2-nl-to-fol-merged/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }

# %%
test_questions = random.sample(list(zip(dataset['validation']['Question'], dataset['validation']['FOL Query'])), 2)

print("Testing model after fine-tuning:")
after_results = test_model(fine_tuned_model, tokenizer, test_questions)
for result in after_results:
    print(f"Question: {result['question']}")
    print(f"Input: {result['input']}")
    print(f"Generated FOL: {result['generated_fol']}")
    print(f"True FOL: {result['true_fol']}\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Testing model after fine-tuning:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Question: Is there a white car at the center of the scene?
# Input: Translate the following natural language question to First Order Logic (FOL). Please respond with only the FOL statement. Don't include additional text.
# Question: Is there a white car at the center of the scene?
# FOL Query:
# Generated FOL: TypeOf(x, Car)^ColorOf(x, White)^InitialLocation(x, NearFront)^TypeOf(y, Car)^InitialLocation(y, NearFront)^InitialLocation(y, NearLeft)^ComeClose(x, y)^InitialLocation(y, NearRight)^ComeClose(y, y)^InitialLocation(x, NearRight)^InitialLocation(y, NearLeft)^InitialLocation(y, Near
# True FOL: TypeOf(x, Car)^ColorOf(x, White)^InitialLocation(x, NearFront)
#
# Question: Is the gray SUV accelerating?
# Input: Translate the following natural language question to First Order Logic (FOL). Please respond with only the FOL statement. Don't include additional text.
# Question: Is the gray SUV accelerating?
# FOL Query:
# Generated FOL: TypeOf(x, SUV)^ColorOf(x, Gray)^Vehicles(x)^Accelerate(x)^InitialLocation(x, NearFront)^InitialLocation(y, NearFront)^InitialLocation(y, NearLeft)^InitialLocation(x, NearRight)^InitialLocation(y, NearRight)^InitialSpeed(x, y)^InitialLocation(y, NearRight)^InitialLocation(x, NearRight)^
# True FOL: TypeOf(x, SUV)^ColorOf(x, Gray)^Vehicles(x)^Accelerate(x)
